# %%
import pandas as pd

# %%
df.sort_values(by=['Timestamp'],ascending = False, inplace=True)

# %%
df.head()
# Out:
#      Unnamed: 0 UserScreenName      UserName                 Timestamp  \
# 662         662        Ligne 9  @Ligne9_RATP  2020-06-17T06:56:46.000Z
# 663         663        Ligne 9  @Ligne9_RATP  2020-06-05T14:23:41.000Z
# 664         664        Ligne 9  @Ligne9_RATP  2020-06-03T09:08:54.000Z
# 665         665        Ligne 9  @Ligne9_RATP  2020-05-17T12:46:02.000Z
# 666         666        Ligne 9  @Ligne9_RATP  2020-05-11T18:13:50.000Z
#
#                                        Text  \
# 662  Ligne 9\n@Ligne9_RATP\n·\nJun 17, 2020
# 663   Ligne 9\n@Ligne9_RATP\n·\nJun 5, 2020
# 664   Ligne 9\n@Ligne9_RATP\n·\nJun 3, 2020
# 665  Ligne 9\n@Ligne9_RATP\n·\nMay 17, 2020
# 666  Ligne 9\n@Ligne9_RATP\n·\nMay 11, 2020
#
#                                          Embedded_text Emojis  Comments  \
# 662  [ Panne de signalisation] 08h52 : le trafic es...      ⚠       2.0
# 663  [  Mesure de sécurité] 16h20 : le trafic est i...      ❌       2.0
# ...
